# %%
# Mount Drive
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# Get the travel info
import requests
import json
from datetime import timedelta

# Load ML Model
import joblib

# Interactive map
import folium

# %% [markdown]
# # Load Data: USGS Dataset

# %%
useful_columns1 = ['t_state','p_name','p_tnum','p_cap',
                   't_manu','t_cap','t_hh','t_rd',
                   't_rsa','t_hh','xlong','ylat']

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Capstone Data/uswtdb_v5_2_20221012.csv',
                 engine='python',encoding='latin1',usecols=useful_columns1)
df1 = df1[df1.t_state=='NY']

# %% [markdown]
# # Predict Turbine Weights

# %%
processed_manu = [x.lower() if type(x)==str else x for x in list(df1['t_manu'])]

for i in range(len(processed_manu)):
  if processed_manu[i] not in ['fuhrlander', 'ge wind','goldwind','nordex','other', 'repower', 'siemens gamesa renewable energy', 'vensys', 'vergnet','vestas']:
    processed_manu[i] = 'other'

df1.insert(1, 'manufacturer_processed', processed_manu)

df1.drop('t_manu',axis=1,inplace=True)

# %%
X = np.array(df1[['manufacturer_processed','t_cap','t_rd','t_rsa','t_hh']])

model_path = '/content/drive/MyDrive/Wind Turbine Capstone Project/Sarosh/xgb_predict_rotor_weight_tons.pkl'
model = joblib.load(model_path)

df1['rotor_weight'] = model.predict(X)

# %%
df1['t_rd'] = df1['t_rd'].fillna(df1['t_rd'].median())

# %%
df1['turbine_blade_weight'] = (1/6) * df1['rotor_weight']
df1['t_blade_length'] = df1['t_rd'] / 2

# %% [markdown]
# # Save Dataset

# %%
project_data = pd.DataFrame(df1.groupby(['p_name','manufacturer_processed'])[['xlong','ylat','p_tnum','t_cap','turbine_blade_weight','t_blade_length']].mean())
project_data.columns = ['longitude','latitude','numb_turbines','avg_turbine_capacity','turbine_blade_weight','turbine_blade_length']
project_data.reset_index(drop=False,inplace=True)
project_data.sort_values(by=['p_name'],ascending=False,inplace=True)
project_data['text'] = 'Project Name: ' + project_data['p_name'] + '<br>Number of Turbines: ' + project_data['numb_turbines'].astype(str) + '<br>Average Turbine Capacity: ' + (project_data['avg_turbine_capacity']).astype(str) + " MW"

# %%
project_data.head()
# Out:
#                        p_name manufacturer_processed  longitude   latitude  \
# 49     unknown Wyoming County                  other -78.187935  42.740818
# 48     unknown Steuben County                  other -77.533662  42.486564
# 47      unknown Oneida County                  other -75.447369  42.975771
# 46     unknown Niagara County                  other -78.493963  43.282899
# 45  unknown Montgomery County                  other -74.510246  42.905187
#
#     numb_turbines  avg_turbine_capacity  turbine_blade_weight  \
# 49            1.0                   NaN               0.66904
# 48           11.0                   NaN               0.66904
# 47            2.0                   NaN               0.66904
# 46            1.0                   NaN               0.66904
# 45            2.0                   NaN               0.66904
#
#     turbine_blade_length                                               text
# 49                  41.0  Project Name: unknown Wyoming County<br>Number...
# 48                  41.0  Project Name: unknown Steuben County<br>Number...
# 47                  41.0  Project Name: unknown Oneida County<br>Number ...
# 46                  41.0  Project Name: unknown Niagara County<br>Number...
# 45                  41.0  Project Name: unknown Montgomery County<br>Num...

# %%
project_data.to_csv('usgs_data.csv')
# !cp usgs_data.csv "drive/My Drive/Capstone Data"

# %% [markdown]
# # Load Data: NYSERDA Dataset

# %%
useful_columns2 = ['Project Name','Renewable Technology','Project Status','Year of Delivery Start Date','Contract Duration',
                  'Georeference']

# %%
df2 = pd.read_excel('/content/drive/MyDrive/Capstone Data/Large-scale_Renewable_Projects_Reported_by_NYSERDA__Beginning_2004_Wind.xlsx',usecols=useful_columns2)
df2 = df2[(df2['Renewable Technology']=='Land Based Wind') | (df2['Renewable Technology']=='Offshore Wind')]
df2 = df2[df2['Project Status']=='Under Development']
df2.reset_index(drop = True, inplace = True)
df2 = df2.rename(columns={"Project Name": "p_name", "Year of Delivery Start Date": "p_year"})

# %% [markdown]
# # Data Cleaning

# %%
# df2['longitude']=df2['Georeference'].str.slice(7, 17)
# df2['latitude']=df2['Georeference'].str.slice(18, 27)
# df2['Georeference'].str.contains('POINT')
df2["clean_name"] = df2["Georeference"].apply(lambda x: str(x).split('(')[1].lstrip().split(')')[0] if "POINT" in str(x) else np.NaN)
df2["longitude"] = df2["clean_name"].apply(lambda x: str(x).split()[0] if " " in str(x) else np.NaN).astype(float)
df2["latitude"] = df2["clean_name"].apply(lambda x: str(x).split()[1] if " " in str(x) else np.NaN).astype(float)
df2.drop('Georeference', axis=1, inplace=True)
df2.drop('clean_name', axis=1, inplace=True)

# %%
for index, location_info in df2.iterrows():
  if pd.notnull(location_info['latitude']):
    print(location_info['p_name'])
# Out:
# Heritage Wind, LLC
# Number Three Wind Farm
# Alle-Catt Wind Farm
# Eight Point Wind
# Ball Hill
# Bluestone Wind
# High Bridge Wind and Battery
# Empire Wind
# Beacon Wind
# Empire Wind 2
# Baron Winds I
# Baron Winds II
# Prattsburgh Wind Farm
# Sunrise Wind

# %% [markdown]
# # Save Dataset

# %%
project_data2 = df2[['p_name', 'p_year', 'longitude', 'latitude']]
project_data2['text'] = 'Project Name: ' + project_data2['p_name'] + '<br>Year of Delivery Start Date: ' + project_data2['p_year'].astype(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
project_data2.head()
# Out:
#                    p_name  p_year  longitude   latitude  \
# 0      Heritage Wind, LLC  2023.0 -78.208094  43.232126
# 1  Number Three Wind Farm  2022.0 -75.472278  43.798604
# 2     Alle-Catt Wind Farm  2025.0 -78.391547  42.572191
# 3        Eight Point Wind  2023.0 -77.686829  42.057570
# 4               Ball Hill  2023.0 -79.167766  42.526680
#
#                                                 text
# 0  Project Name: Heritage Wind, LLC<br>Year of De...
# 1  Project Name: Number Three Wind Farm<br>Year o...
# 2  Project Name: Alle-Catt Wind Farm<br>Year of D...
# 3  Project Name: Eight Point Wind<br>Year of Deli...
# 4  Project Name: Ball Hill<br>Year of Delivery St...

# %%
project_data2.to_csv('nyserda_data.csv')
# !cp nyserda_data.csv "drive/My Drive/Capstone Data"

# %% [markdown]
# # Load Data: Tracy's radius dataset

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Capstone Data/farms_loc_radius.csv')

# %%
df3['ghg_radius_miles'] = df3['ghg_radius_m']/1609.34
df3 = df3.rename(columns={"xlong": "longitude", "ylat": "latitude"})
df3.head()
# Out:
#                       p_name  longitude   latitude  ghg_radius_m  \
# 0           Arkwright Summit -79.231833  42.407748       19872.4
# 1                  Cassadaga -79.174704  42.315485       19493.1
# 2                 Copenhagen -75.639337  43.890878       20474.0
# 3        Dutch Hill/Cohocton -77.454707  42.533052       35746.6
# 4  Fenner Wind Power Project -75.760677  42.989136       10397.6
#
#    ghg_radius_miles
# 0         12.348168
# 1         12.112481
# 2         12.721985
# 3         22.211963
# 4          6.460785

# %%
df3.to_csv('ghg_radius_data.csv')
# !cp ghg_radius_data.csv "drive/My Drive/Capstone Data"

# %% [markdown]
# # Load Data: State Park Facility Points

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Capstone Data/State_Park_Facility_Points.csv')
df4 = df4[df4.Category.str.contains('Park')]
df4.reset_index(drop = True, inplace = True)
df4 = df4[['Name','Longitude','Latitude']]

# %%
df4.head()
# Out:
#                 Name  Longitude   Latitude
# 0       Watkins Glen -76.900134  42.367540
# 1  FDR Four Freedoms -73.960379  40.750677
# 2          Mine Kill -74.461121  42.434025
# 3            Amherst -78.748088  42.971001
# 4      Montauk Point -71.881388  41.071450

# %%
df4.to_csv('state_park_data.csv')
# !cp state_park_data.csv "drive/My Drive/Capstone Data"

# %% [markdown]
# # Load Data: Active Capital Projects, NYS Thruway Authority

# %%
df5 = pd.read_csv('/content/drive/MyDrive/Capstone Data/Capital_Projects__NYS_Thruway_Authority_Capital_Programs__Beginning_2005.csv')
df5.dropna(subset=['Latitude','Longitude'], inplace = True)
df5.reset_index(drop = True, inplace = True)
df5 = df5[['DIVISION','ID','Longitude','Latitude']]
df5['text'] = df5['DIVISION'] + ' ' + df5['ID']

# %%
df5.head()
# Out:
#    DIVISION       ID  Longitude   Latitude              text
# 0    Albany   C172.1 -74.211062  42.946016     Albany C172.1
# 1  Syracuse  H1118.1 -76.924232  42.958034  Syracuse H1118.1
# 2    Albany    C67.1 -73.701738  42.802867      Albany C67.1
# 3   Buffalo   B556.2 -78.940905  43.000894    Buffalo B556.2
# 4  Syracuse   H911.2 -76.233375  43.118117   Syracuse H911.2

# %%
df5.to_csv('thruway_authority_data.csv')
# !cp thruway_authority_data.csv "drive/My Drive/Capstone Data"

# %% [markdown]
# # Create Map

# %%
windfarm1 = pd.read_csv('/content/drive/MyDrive/Capstone Data/usgs_data.csv')

# %%
windfarm2 = pd.read_csv('/content/drive/MyDrive/Capstone Data/nyserda_data.csv')

# %%
ghg_circle = pd.read_csv('/content/drive/MyDrive/Capstone Data/ghg_radius_data.csv')

# %%
map = folium.Map(location = [ghg_circle.latitude.mean(), ghg_circle.longitude.mean()], zoom_start=7, control_scale=True)
# for i in range(0,len(ghg_circle)):
#    folium.Circle(
#       location=[ghg_circle.iloc[i]['latitude'], ghg_circle.iloc[i]['longitude']],
#       popup=ghg_circle.iloc[i]['p_name'],
#       radius=float(ghg_circle.iloc[i]['ghg_radius_m']),
#       color='crimson',
#       fill=True,
#       fill_color='crimson'
#    ).add_to(map)
for index, location_info in ghg_circle.iterrows():
    folium.Circle(
        location = [location_info["latitude"], location_info["longitude"]], 
        radius = location_info['ghg_radius_m'],
        color='crimson',
        fill=True,
        fill_color='crimson',
        popup = folium.Popup(location_info["p_name"])
        ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42a6bd33ca0a17cc4b2d853066e83699 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42a6bd33ca0a17cc4b2d853066e83699&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42a6bd33ca0a17cc4b2d853066e83699 = L.map(
#                 &quot;map_42a6bd33ca0a17cc4b2d853066e83699&quot;,
#                 {
#                     center: [42.80893988538001, -76.40789211936716],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_42a6bd33ca0a17cc4b2d853066e83699);
#
#
#
#
#
#             var tile_layer_fa5e1b438dc68783430e0db8420da06b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42a6bd33ca0a17cc4b2d853066e83699);
#
#
#             var circle_f183d54c31c1b84d86ef92d83baf5c30 = L.circle(
#                 [42.40774783333333, -79.23183255555556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19872.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42a6bd33ca0a17cc4b2d853066e83699);
#
#
#         var popup_0cdaf015693f6abe7beb6bbdd3cc1758 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fd470767606ee67204317102117fd3e1 = $(`&lt;div id=&quot;html_fd470767606ee67204317102117fd3e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkwright Summit&lt;/div&gt;`)[0];
#             popup_0cdaf015693f6abe7beb6bbdd3cc1758.setContent(html_fd470767606ee67204317102117fd3e1);
#
#
#         circle_f183d54c31c1b84d86ef92d83baf5c30.bindPopup(popup_0cdaf015693f6abe7beb6bbdd3cc1758)
#         ;
#
#
#
#
#             var circle_070f1d50d40cccd865e483db06dbc551 = L.circle(
#                 [42.31548521621622, -79.17470372972973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19493.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42a6bd33ca0a17cc4b2d853066e83699);
#
#
#         var popup_e3e6e09f0515275d5f97ddecd787b263 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4fa3dd8def3b1f0d7db233d9346f8c27 = $(`&lt;div id=&quot;html_4fa3dd8def3b1f0d7db233d9346f8c27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cassadaga&lt;/div&gt;`)[0];
#             popup_e3e6e09f0515275d5f97ddecd787b263.setContent(html_4fa3dd8def3b1f0d7db233d9346f8c27);
#
#
#         circle_070f1d50d40cccd865e483db06dbc551.bindPopup(popup_e3e6e09f0515275d5f97ddecd787b263)
#         ;
#
#
#
#
#             var circle_9bd0cc28e5d4f14b081f993a8350d754 = L.circle(
#                 [43.890877725, -75.6393374],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20474.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42a6bd33ca0a17cc4b2d853066e83699);
#
#
#         var popup_b0e04dbfec7b318e9c41f10bdb061364 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_011dea9704057f525411b4d6f916a53c = $(`&lt;div id=&quot;html_011dea9704057f525411b4d6f916a53c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Copenhagen&lt;/div&gt;`)[0];
#             popup_b0e04dbfec7b318e9c41f10bdb061364.setContent(html_011dea9704057f525411b4d6f916a53c);
#
#
#         circle_9bd0cc28e5d4f14b081f993a8350d754.bindPopup(popup_b0e04dbfec7b318e9c41f10bdb061364)
#         ;
#
#
#
#
#             var circle_96911aa3448165d1aa929bdf8fe78dc7 = L.circle(
#                 [42.53305176, -77.45470686],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineC

# %%
map = folium.Map(location = [windfarm1.latitude.mean(), windfarm1.longitude.mean()], zoom_start=7, control_scale=True)

group0 = folium.FeatureGroup(name='<span style=\\"color: blue;\\">Exist Projects</span>')
for index, location_info in windfarm1.iterrows():

    folium.CircleMarker(
        location = [location_info["latitude"], location_info["longitude"]], 
        radius = location_info['numb_turbines']/2,
        fill_color ='blue',
        popup = folium.Popup(location_info["text"], min_width=250, max_width=250)
        ).add_to(group0)
group0.add_to(map)

group1 = folium.FeatureGroup(name='<span style=\\"color: orange;\\">Future Projects</span>')
for index, location_info in windfarm2.iterrows():
    if pd.notnull(location_info['latitude']):
        folium.CircleMarker(
        location = [location_info["latitude"], location_info["longitude"]], 
        radius = 5,
        color = 'orange',
        fill_color ='red',
        popup = folium.Popup(location_info["text"], min_width=250, max_width=250)
        ).add_to(group1)
group1.add_to(map)

folium.map.LayerControl('topleft', collapsed=False).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1450ebd93a84da96c0a25b4b740e9b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1450ebd93a84da96c0a25b4b740e9b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1450ebd93a84da96c0a25b4b740e9b9 = L.map(
#                 &quot;map_c1450ebd93a84da96c0a25b4b740e9b9&quot;,
#                 {
#                     center: [43.037998584096876, -76.59024501089947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c1450ebd93a84da96c0a25b4b740e9b9);
#
#
#
#
#
#             var tile_layer_a94bee899987dd61bcf02e125f600d64 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1450ebd93a84da96c0a25b4b740e9b9);
#
#
#             var feature_group_e6f1f572725bc06ece0b41d68b01a5ea = L.featureGroup(
#                 {}
#             ).addTo(map_c1450ebd93a84da96c0a25b4b740e9b9);
#
#
#             var circle_marker_18f32097fe56f20e2fdf39d824a531b4 = L.circleMarker(
#                 [42.740818, -78.187935],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e6f1f572725bc06ece0b41d68b01a5ea);
#
#
#         var popup_1926a7026b00ee1f25a3b4676b674c01 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var html_b6166e37d5e2f421517bcf2a3f0eade6 = $(`&lt;div id=&quot;html_b6166e37d5e2f421517bcf2a3f0eade6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Project Name: unknown Wyoming County&lt;br&gt;Number of Turbines: 1.0&lt;br&gt;Average Turbine Capacity: nan MW&lt;/div&gt;`)[0];
#             popup_1926a7026b00ee1f25a3b4676b674c01.setContent(html_b6166e37d5e2f421517bcf2a3f0eade6);
#
#
#         circle_marker_18f32097fe56f20e2fdf39d824a531b4.bindPopup(popup_1926a7026b00ee1f25a3b4676b674c01)
#         ;
#
#
#
#
#             var circle_marker_72af131a41960603a2ca556c078679df = L.circleMarker(
#                 [42.4865639090909, -77.53366227272727],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e6f1f572725bc06ece0b41d68b01a5ea);
#
#
#         var popup_5f2e9c35040b2b94564fd21fae541264 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var html_7a8ec2e0ad51d85ac5fdfe4e6e949219 = $(`&lt;div id=&quot;html_7a8ec2e0ad51d85ac5fdfe4e6e949219&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Project Name: unknown Steuben County&lt;br&gt;Number of Turbines: 11.0&lt;br&gt;Average Turbine Capacity: nan MW&lt;/div&gt;`)[0];
#             popup_5f2e9c35040b2b94564fd21fae541264.setContent(html_7a8ec2e0ad51d85ac5fdfe4e6e949219);
#
#
#         circle_marker_72af131a41960603a2ca556c078679df.bindPopup(popup_5f2e9c35040b2b94564fd21fae541264)
#         ;
#
#
#
#
#             var circle_marker_cb5512a2fa67c75ae2d04dfd0b0b2557 = L.circleMarker(
#                 [42.975771, -75.44736900000001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e6f1f572725bc06ece0b41d68b01a5ea);
#
#
#         var popup_1fa39706152b361f440d8172f7fe80cd = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var html_2a259d9eeb9b046110156dce0ed91d86 = $(`&lt;div id=&quot;html_2a259d9eeb9b046110156dce0ed91d86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Project Name: unknown Oneida County&lt;br&gt;Number of Turbines: 2.0&lt;br&gt;Average Turbine Capacity: nan MW&lt;/div&gt;`)[0];
#             popup_1fa39706152b361f440d8172f7fe80cd.setContent(html_2a259d9eeb9b046110156dce0ed91d
