# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# # Load Data

# %%
column_descrip = pd.read_csv('../../data/raw/usgs/usgs_data_dictionary.csv')
column_descrip
# Out:
#             field                                         category  \
# 0         case_id                                               id
# 1         faa_ors                                               id
# 2         faa_asn                                               id
# 3      usgs_pr_id                                               id
# 4          eia_id                                               id
# 5         t_state                                         location
# 6        t_county                                         location
# 7          t_fips                                         location
# 8          p_name                           project characteristic
# 9          p_year                           project characteristic
# 10         p_tnum                           project characteristic
# 11          p_cap                           project characteristic
# 12         t_manu                           turbine characteristic
# 13        t_model                           turbine characteristic
# 14          t_cap                           turbine characteristic
# 15           t_hh                           turbine characteristic
# 16           t_rd                           turbine characteristic
# 17          t_rsa                           turbine characteristic
# 18         t_ttlh                           turbine characteristic
# 19       retrofit                           turbine characteristic
# 20  retrofit_year                           turbine characteristic
# 21     t_conf_atr                    turbine characteristics qa/qc
# 22     t_conf_loc                          visual inspection qa/qc
# 23     t_img_date                           visual inspection info
# 24     t_img_srce                           visual inspection info
# 25          xlong                                         location
# 26           ylat                                         location
# 27            NaN                                              NaN
# 28            NaN                                              NaN
# 29       Acronyms                                              NaN
# 30            ASN                        Aeronautical Study Number
# 31            ACP                 American Clean Power Association
# 32            DOF                            Digital Obstacal File
# 33            FAA                 Federal Avaiation Administration
# 34           LBNL            Lawrence Berkeley National Laboratory
# 35         OE/AAA  Obstacle Evaluation / Airport Airspace Analysis
# 36            ORS                       Obstacle Repository System
# 37           USGS                  United States Geological Survey
# 38            EIA                Energy Information Administration
# 39            NaN                                              NaN
# 40     t_conf_loc                                              NaN
# 41           code                                short description
# 42              0                            Not visually verified
# 43              1                                    No confidence
# 44              2                               Partial confidence
# 45              3                                  Full confidence
# 46            NaN                                              NaN
# 47     t_conf_atr                                              NaN
# 48           code                                short description
# 49              0                                     Not verified
# 50              1                                    No confidence
# 51              2                               Partial confidence
# 52              3                                  Full confidence
# 53            NaN                                              NaN
# 54       retrofit                                              NaN
# 55           code                                short description
# 56              0                                               No
# 57              1                                              Yes
#
#                                           description    type  non-missing  \
# 0                                    unique uswtdb id    long      72130.0
# 1   faa digital obstacle file (dof) for obstacle r...    str9      66586.0
# 2   faa obstruction evaluation - airport airspace ...   str17      66877.0
# 3                  usgs id from prior turbine dataset    long      38095.0
# 4                      eia plant id from eia form 860    long      65445.0
# 5                      state where turbine is located    str2      72130.0
# 6                     county where turbine is located   str31      72130.0
# 7      state and county fips where turbine is located    str5      72130.0
# 8                                        project name   str42      72130.0
# 9                     year project became operational     int      71398.0
# 10                      number of turbines in project     int      72130.0
# 11                              project capacity (MW)  double      68204.0
# 12            turbine original equipment manufacturer   str31      67045.0
# 13                                      turbine model   str18      66908.0
# 14                              turbine capacity (kW)     int      67216.0
# 15                        turbine hub height (meters)  double      66685.0
# 16                    turbine rotor diameter (meters)  double      66778.0
# 17                turbine rotor swept area (meters^2)  double      66778.0
# 18         turbine total height - calculated (meters)  double      66685.0
# 19  indicator of whether the turbine has been part...    byte      72130.0
# 20              year in which turbine was retrofitted     int       6738.0
# 21            turbine characteristic confidence (0-3)    byte      72130.0
# 22                         location confidence (0 -3)    byte      72130.0
# 23  date of image used to visually verify turbine ...     int      63984.0
# 24  source of image used to visually verify turbin...   str16      72130.0
# 25         longitude (decimal degrees - NAD 83 datum)  double      72130.0
# 26          latitude (decimal degrees - NAD 83 datum)  double      72130.0
# 27                                                NaN     NaN          NaN
# 28                                                NaN     NaN          NaN
# 29                                                NaN     NaN          NaN
# 30                                                NaN     NaN          NaN
# 31                                                NaN     NaN          NaN
# 32                                                NaN     NaN          NaN
# 33                                                NaN     NaN          NaN
# 34                                                NaN     NaN          NaN
# 35                                                NaN     NaN          NaN
# 36                                                NaN     NaN          NaN
# 37                                                NaN     NaN          NaN
# 38                                                NaN     NaN          NaN
# 39                                                NaN     NaN          NaN
# 40                                                NaN     NaN          NaN
# 41                                   long description     NaN          NaN
# 42  Not visually verified: Point has not been visu...     NaN          NaN
# 43  No confidence: No turbine shown in image; imag...     NaN          NaN
# 44  Partial confidence: image shows a developed pa...     NaN          NaN
# 45  Full confidence: image shows an installed turb...     NaN          NaN
# 46                                                NaN     NaN          NaN
# 47                                                NaN     NaN          NaN
# 48                                   long description     NaN          NaN
# 49    Not verified: attributes have not been verified     NaN          NaN
# 50  No confidence: no facility data, no name, noth...     NaN          NaN
# 51  Partial confidence: incomplete information or ...     NaN          NaN
# 52  Full confidence: consistent information across...     NaN          NaN
# 53                                                NaN     NaN          NaN
# 54                                                NaN     NaN          NaN
# 55                                   long description     NaN          NaN
# 56  Turbine has not been significantly retrofitted...     NaN          NaN
# 57  Turbine has been significantly retrofitted (i....     NaN          NaN
#
#        Labels           Min           Max
# 0         NaN  3.000001e+06  3.124485e+06
# 1         NaN           NaN           NaN
# 2         NaN           NaN           NaN
# 3         NaN  1.000000e+00  4.913500e+04
# 4         NaN  9.000000e+01  6.527000e+04
# 5         NaN           NaN           NaN
# 6         NaN           NaN           NaN
# 7         NaN           NaN           NaN
# 8         NaN           NaN           NaN
# 9         NaN  1.981000e+03  2.022000e+03
# 10        NaN  1.000000e+00  7.310000e+02
# 11        NaN  5.000000e-02  1.055600e+03
# 12        NaN           NaN           NaN
# 13        NaN           NaN           NaN
# 14        NaN  5.000000e+01  6.000000e+03
# 15        NaN  1.900000e+01  1.370000e+02
# 16        NaN  1.340000e+01  1.550000e+02
# 17        NaN  1.410300e+02  1.886919e+04
# 18        NaN  3.040000e+01  2.054000e+02
# 19        NaN  0.000000e+00  1.000000e+00
# 20        NaN  2.015000e+03  2.021000e+03
# 21  see below  1.000000e+00  3.000000e+00
# 22  see below  1.000000e+00  3.000000e+00
# 23        NaN           NaN           NaN
# 24        NaN           NaN           NaN
# 25        NaN -1.717131e+02  1.447227e+02
# 26        NaN  1.338940e+01  6.683990e+01
# 27        NaN           NaN           NaN
# 28        NaN           NaN           NaN
# 29        NaN           NaN           NaN
# 30        NaN           NaN           NaN
# 31        NaN           NaN           NaN
# 32        NaN           NaN           NaN
# 33        NaN           NaN           NaN
# 34        NaN           NaN           NaN
# 35        NaN           NaN           NaN
# 36        NaN           NaN           NaN
# 37        NaN           NaN           NaN
# 38        NaN           NaN           NaN
# 39        NaN           NaN           NaN
# 40        NaN           NaN           NaN
# 41        NaN           NaN           NaN
# 42        NaN           NaN           NaN
# 43        NaN           NaN           NaN
# 44        NaN           NaN           NaN
# 45        NaN           NaN           NaN
# 46        NaN           NaN           NaN
# 47        NaN           NaN           NaN
# 48        NaN           NaN           NaN
# 49        NaN           NaN           NaN
# 50        NaN           NaN           NaN
# 51        NaN           NaN           NaN
# 52        NaN           NaN           NaN
# 53        NaN           NaN           NaN
# 54        NaN           NaN           NaN
# 55        NaN           NaN           NaN
# 56        NaN           NaN           NaN
# 57        NaN           NaN           NaN

# %%
useful_columns = ['case_id','t_state','t_county','t_fips','p_name','p_year',
                  'p_tnum','p_cap','t_manu','t_model','t_cap','t_hh','t_rd',
                  't_rsa','t_ttlh','xlong','ylat']

# %%
column_descrip[column_descrip['field'].isin(useful_columns)][['field','description']]
# Out:
#        field                                     description
# 0    case_id                                unique uswtdb id
# 5    t_state                  state where turbine is located
# 6   t_county                 county where turbine is located
# 7     t_fips  state and county fips where turbine is located
# 8     p_name                                    project name
# 9     p_year                 year project became operational
# 10    p_tnum                   number of turbines in project
# 11     p_cap                           project capacity (MW)
# 12    t_manu         turbine original equipment manufacturer
# 13   t_model                                   turbine model
# 14     t_cap                           turbine capacity (kW)
# 15      t_hh                     turbine hub height (meters)
# 16      t_rd                 turbine rotor diameter (meters)
# 17     t_rsa             turbine rotor swept area (meters^2)
# 18    t_ttlh      turbine total height - calculated (meters)
# 25     xlong      longitude (decimal degrees - NAD 83 datum)
# 26      ylat       latitude (decimal degrees - NAD 83 datum)

# %%
df = pd.read_csv('../../data/raw/usgs/usgs_data.csv',
                 engine='python',encoding='latin1',usecols=useful_columns)
# We want only New York data
df = df[df.t_state=='NY']

# %%
df.head()
# Out:
#       case_id t_state           t_county  t_fips            p_name  p_year  \
# 1528  3075480      NY  Chautauqua County   36013  Arkwright Summit  2018.0
# 1529  3075488      NY  Chautauqua County   36013  Arkwright Summit  2018.0
# 1530  3075460      NY  Chautauqua County   36013  Arkwright Summit  2018.0
# 1531  3075489      NY  Chautauqua County   36013  Arkwright Summit  2018.0
# 1532  3075456      NY  Chautauqua County   36013  Arkwright Summit  2018.0
#
#       p_tnum  p_cap  t_manu   t_model   t_cap  t_hh   t_rd    t_rsa  t_ttlh  \
# 1528      36   78.4  Vestas  V110-2.0  2200.0  95.0  110.0  9503.32   150.0
# 1529      36   78.4  Vestas  V110-2.0  2200.0  95.0  110.0  9503.32   150.0
# 1530      36   78.4  Vestas  V110-2.0  2200.0  95.0  110.0  9503.32   150.0
# 1531      36   78.4  Vestas  V110-2.0  2000.0  95.0  110.0  9503.32   150.0
# 1532      36   78.4  Vestas  V110-2.0  2000.0  95.0  110.0  9503.32   150.0
#
#           xlong       ylat
# 1528 -79.230286  42.395222
# 1529 -79.245026  42.427578
# 1530 -79.222168  42.388699
# 1531 -79.252396  42.430599
# 1532 -79.232803  42.430202
